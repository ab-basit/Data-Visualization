# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Distplot()

# %%
sns.distplot(tips['total_bill'])

# %% [markdown]
# The curve is Kernal Density Estimate, To remove this set the kde = False

# %%
sns.distplot(tips['total_bill'],kde=False)

# %% [raw]
# we can change the number of histogram bars by setting bins=?

# %% [markdown]
# * **A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.**
# * **A rug is a line instead of point at each observation point.**
# * **Drawing a KDE is more computationally involved than drawing a histogram. What happens is that each observation is first replaced with a normal (Gaussian) curve centered at that value..For each point there is a curve of normal distribution.Next, these curves are summed to compute the value of the density at each point in the support grid. The resulting curve is then normalized so that the area under it is equal to 1:**

# %% [markdown]
# We can show only kde curve,histogram or rug(line instead of point at observation) by setting corresponding values as :
# ## True/False

# %%
sns.distplot(tips.total_bill,hist=False)

# %%
sns.distplot(tips.total_bill,kde=False,rug=True,hist=False)

# %% [markdown]
# # Jointplot()

# %% [raw]
# jointplot(x=col1,y=col2,data=?/dataset,kind=?)
# allows you to basically match up two distplots for bivariate data. With your choice of what 'kind' parameter to compare with:
# “scatter”
# “reg”
# “resid”
# “kde”
# “hex”

# %%
 sns.jointplot(x=tips.total_bill,y=tips.tip,data=tips)

# %%
sns.jointplot(tips.total_bill,tips.tip,kind='hex')

# %% [markdown]
# ## pairplot
#
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')#,palette='coolwarm')

# %% [markdown]
# ## rugplot
#
# rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot:

# %%
sns.rugplot(tips.total_bill)

# %% [markdown]
# ## kdeplot
#
# kdeplots are [Kernel Density Estimation plots](http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth). These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value. For example:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c1bb0653f159> in <module>()
# ----> 1 type(NaN)
#
# NameError: name 'NaN' is not defined

# %%
import numpy as np

# %%
type(np.nan)
# Out:
# float

# %%
import pandas as pd
from pandas import Series ,DataFrame

# %%
df = DataFrame(np.arange(25).reshape(5,5),index=list('abcde'),columns=list('vwxyz'))

# %%
df
# Out:
#     v   w   x   y   z
# a   0   1   2   3   4
# b   5   6   7   8   9
# c  10  11  12  13  14
# d  15  16  17  18  19
# e  20  21  22  23  24

# %%
df.ix[:3,3]=np.nan
# Out:
# C:\Users\Administrator\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     v   w   x     y   z
# a   0   1   2   NaN   4
# b   5   6   7   NaN   9
# c  10  11  12   NaN  14
# d  15  16  17  18.0  19
# e  20  21  22  23.0  24

# %%
df.iloc[:4,4]=np.nan

# %%
df
# Out:
#     v   w   x     y     z
# a   0   1   2   NaN   NaN
# b   5   6   7   NaN   NaN
# c  10  11  12   NaN   NaN
# d  15  16  17  18.0   NaN
# e  20  21  22  23.0  24.0

# %%
df.loc[:2,'w']=np.nan

# %%
df.loc[:'c','v']=np.nan

# %%
df
# Out:
#       v     w   x     y     z   2
# a   NaN   NaN   2   NaN   NaN NaN
# b   NaN   NaN   7   NaN   NaN NaN
# c   NaN  11.0  12   NaN   NaN NaN
# d  15.0  16.0  17  18.0   NaN NaN
# e  20.0  21.0  22  23.0  24.0 NaN
